# %%
# import sys
#open "jupyter notebook" from anaconda prompt and then run this
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.4.5 pyspark-shell'
from elasticsearch import helpers
from elasticsearch import Elasticsearch
from ownelastic import sth2elastic
from pyspark.sql import *
from pyspark import SparkContext, SparkConf
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils
import json
from pyspark.sql.functions import lit
from pyspark.sql.functions import udf
from pyspark.sql.types import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from datetime import datetime


import nltk
nltk.download('vader_lexicon')

# create instance of elasticsearch
#es = Elasticsearch("http://localhost:9200")

elasticurl = "http://localhost"

def getElastic():
    return Elasticsearch([elasticurl + ':9200'], timeout=30)

#pushing data into elastice search with index
def sth2elastic(doc, index, type):
    #getting the elasticeseach initialization
    esclient = getElastic()
    statcnt = 0
    actions = []
    for row in doc:
        #print("inside elastic: ", row)
        actions.append({
            "_op_type": "index",
            "_index": index,
            "_type": type,
            "_source": row
        })

    for ok, response in helpers.streaming_bulk(esclient, actions, index=index, doc_type=type,max_retries=5,raise_on_error=False, raise_on_exception=False):
        if not ok:
            statcnt+=0
            print(response)
        else:
            statcnt += 1
    return statcnt

def getSqlContextInstance(sparkContext):
    if ('sqlContextSingletonInstance' not in globals()):
        globals()['sqlContextSingletonInstance'] = SQLContext(sparkContext)
    return globals()['sqlContextSingletonInstance']

#do the sentiment using VEDAR analylser
def sentimentAnalysis(tweet):
    scores = dict([('pos', 0), ('neu', 0), ('neg', 0), ('compound', 0)])
    sid = SentimentIntensityAnalyzer()
    ss = sid.polarity_scores(tweet)
    for k in sorted(ss):
        #print('inside k', k)
        scores[k] += ss[k]
    return json.dumps(scores)

def do_process(time, rdd):
    print("========= %s =========" % str(time))
    try:
        if rdd.count()==0: raise Exception('Waiting for data....') #Empty
        sqlContext = getSqlContextInstance(rdd.context)
        df = sqlContext.read.json(rdd)
        df = df.filter("text not like 'RT @%'")
        if df.count() == 0: raise Exception('Waiting for data....') #Empty
        #print(df.take(20))    
        #calculating polcarity using VEDAR analyser
        udf_func = udf(lambda x: sentimentAnalysis(x),returnType=StringType())
        df = df.withColumn("sentiment",lit(udf_func(df.text)))
        #print("after sentiment:", df.take(10))
        results = df.toJSON().map(lambda j: json.loads(j)).collect()
        #print("to json after sentiment ", results)
        for result in results:
            result["date"] = datetime.strptime(result["date"], '%a %b %d %H:%M:%S %z %Y')            
            result["sentiment"] = json.loads(result["sentiment"])
            #calculating polalirty(i.e.,negative/postive/neutral) based on compound
            
            #print("Tweet text is : ", result["text"]) 
            #print("Overall sentiment dictionary is : ", result["sentiment"]) 
            #print("sentence was rated as ", result["sentiment"]['neg']*100, "% Negative") 
            #print("sentence was rated as ", result["sentiment"]['neu']*100, "% Neutral") 
            #print("sentence was rated as ", result["sentiment"]['pos']*100, "% Positive") 

            #format(temp, '.2f')
            result["negative_pecentage"] = format(result["sentiment"]['neg']*100, '.2f')
            result["neutral_percentage"] = format(result["sentiment"]['neu']*100, '.2f')
            result["positive_percentage"] = format(result["sentiment"]['pos']*100, '.2f')
            
            #print("Sentence Overall Rated As", end = " ") 

            # decide sentiment as positive, negative and neutral 
            if result["sentiment"]['compound'] >= 0.05 : 
                #print("Positive") 
                result["sentiment_type"] = "positive"

            elif result["sentiment"]['compound'] <= - 0.05 : 
                #print("Negative") 
                result["sentiment_type"] = "negative"

            else : 
                #print("Neutral") 
                result["sentiment_type"] = "neutral"

            #result["sentiment_type"] = "none"
            #if result["sentiment"]['compound'] > 0.05:
                #result["sentiment_type"] = "positive"
                #print("old cal POSITIVE")
            #elif result["sentiment"]['compound'] > -0.05 and result["sentiment"]['compound'] < 0.05 :
                #result["sentiment_type"] = "neutral"
                #print("old cal NEUTRAL")
            #elif result["sentiment"]['compound'] <= -0.05:
                #result["sentiment_type"] = "negative"
                #print("old cal NEGATIVE")
        #pushing data into elasticsearch
        print("after sentiment and before push to elastice search: ", results)
        sth2elastic(results,"tweets_new","doc")
    except Exception as e:
        print(e)
        pass


if __name__ == "__main__":
    conf = SparkConf()
    conf.setMaster("local[4]")
    conf.setAppName("TwitterStreaming")
    # Initialize a SparkContext
    sc = SparkContext.getOrCreate(conf=conf)
    
    ssc = StreamingContext(sc, 10)
  
    #consume the tweets from consumer with tweets_new topic
    kafkaStream = KafkaUtils.createStream(ssc, "localhost:2181", "consumer-group", {"tweets_new": 1})
    
    lines = kafkaStream.map(lambda x: json.loads(x[1]))
    
    lines.foreachRDD(do_process)

    ssc.start()
    ssc.awaitTermination()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\shiva\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# ========= 2020-04-18 17:07:20 =========
# Fetching....
# ========= 2020-04-18 17:07:30 =========
# [Row(date='Sat Apr 18 22:06:15 +0000 2020', text="Someone is fixin' to get audited!", user='agargmd'), Row(date='Sat Apr 18 22:06:15 +0000 2020', text='Is #Trump on his period or something???\n🤔🤔🤔🤔🤔\n#MANopause #COVID #PressBriefing #PressConference #BreakingNews #POTUS #TrumpLiesAmericansDie #TrumpMeltdown #TrumpIsTheWORSTPresidentEVER #TrumpLiesPeopleDie https://t.co/NwJc1maVyd', user='mmtexas'), Row(date='Sat Apr 18 22:06:17 +0000 2020', text="Fucking RESTOCK Looks like I'll be at home until January 20th 2021\n#25thAmendmentNow #GOPBetrayedAmerica #Trump #TrumpLiesAmericansDie #VoteBlue #VoteBlueNoMatterWho #VoteBlue2020 #Biden2020 #TrumpOwnsEveryDeath #COVID https://t.co/IpZdoQkCge", user='LaurieWalters19'), Row(date='Sat Apr 18 22:06:18 +0000 2020', text='@realphilhendrie I find it strange that being tough on China isn’t universal. #Trump is a weakling .', user='ProHulaHooper'), Row(date='Sat Apr 18 22:06:20 +0000 2020', text='#Trump "They\'re trying to take your guns away in Virginia."\n#WhiteHousePressBriefing', user='sherylkahn'), Row(date='Sat Apr 18 22:06:21 +0000 2020', text='"Mark Meadows"   TRUMP\n\nThinks Reporters asking Legit Questions of his\nLeadership failings..."Nasty"\n\nBut hookers pissing on him\nwhile spanking his butt is not~?\n\nWhat an animal~!\n#MAGA #Trump #GOP https://t.co/Rajl30euCG', user='MrAmerica'), Row(date='Sat Apr 18 22:06:21 +0000 2020', text='When you find out PLEASE let us all know! \n@realDonaldTrump', user='Tionia'), Row(date='Sat Apr 18 22:06:23 +0000 2020', text='surely we must be nearing the end of this painful farce? #Trump #TrumpPressConf #POTUS45', user='holditrightnow'), Row(date='Sat Apr 18 22:06:25 +0000 2020', text='@OregonGovBrown https://t.co/M6l5xyfSdQ\nAnd #dumbass #Trump wants to reopen the economy that will kill more Americans!', user='forcemultstevea'), Row(date='Sat Apr 18 22:06:25 +0000 2020', text='Hey, @realdonaldtrump. Go to Hell, Mr President, Sir, and do Planet Earth a big favour. Thanks. #Trump', user='67Snowy'), Row(date='Sat Apr 18 22:06:26 +0000 2020', text='Love when President #Trump compares the plight of Rosa Parks to the fight for Americans to keep their guns...\n#WhiteHousePressBriefing #whitehousePressconference', user='PFMTunein'), Row(date='Sat Apr 18 22:06:28 +0000 2020', text="@WhiteHouse @realDonaldTrump Tweets that didn't age well\n\nhttps://t.co/DwZxGv7RU4", user='FAK___'), Row(date='Sat Apr 18 22:06:28 +0000 2020', text='Modeling has hit the big time', user='PaulFishwick'), Row(date='Sat Apr 18 22:06:30 +0000 2020', text='Birx u SoB.. u have lost ur character &amp; integrity for an incompetent narcissist. U have blood on ur hands like #Trump.. 38k+ ppl have died bcuz of this incompetent @POTUS. @PressSec @PaulaReidCBS #AMJoy @Lawrence', user='NETRetired'), Row(date='Sat Apr 18 22:06:30 +0000 2020', text="It's a fucking outright travesty that #Trump is in charge of a country like the US. Biased, incompetent, ignorant and stupid, it would appear 🥺", user='adozenunholyowl'), Row(date='Sat Apr 18 22:06:30 +0000 2020', text='If you use the word, “frankly,” you’re probably lying. #Trump', user='andytuck'), Row(date='Sat Apr 18 22:06:30 +0000 2020', text='@ElNoPower @realDonaldTrump How about "#Biden 2020 - he\'s definitely not that lying sack of 💩 #Trump."', user='jbwillis021'), Row(date='Sat Apr 18 22:06:33 +0000 2020', text='The economic #RESET by President #Trump is working. American companies are leaving China and returning to the USA. American #economy will soon be booming again and the world will watch with admiration.\n\nhttps://t.co/eUcmO0ViCQ', user='BOSSMAKERtm'), Row(date='Sat Apr 18 22:06:34 +0000 2020', text='Was #OANN told to ask that question before #PressBriefing  #Trump ?', user='MakingTownsGuy'), Row(date='Sat Apr 18 22:06:36 +0000 2020', text='#Trump is a dangerous idiot, and his people are dying, BUT he is kept in power by #murdoch through #foxnews. The blame rests with #murdoch', user='LilyGreenLily')]
# after sentiment: [Row(date='Sat Apr 18 22:06:15 +0000 2020', text="Someone is fixin' to get audited!", user='agargmd', sentiment='{"pos": 0.0, "neu": 1.0, "neg": 0.0, "compound": 0.0}'), Row(date='Sat Apr 18 22:06:15 +0000 2020', text='Is #Trump on his period or something???\n🤔🤔🤔🤔🤔\n#MANopause #COVID #PressBriefing #PressConference #BreakingNews #POTUS #TrumpLiesAmericansDie #TrumpMeltdown #TrumpIsTheWORSTPresidentEVER #TrumpLiesPeopleDie https://t.co/NwJc1maVyd', user='mmtexas', sentiment='{"pos": 0.0, "neu": 1.0, "neg": 0.0, "compound": 0.0}'), Row(date='Sat Apr 18 22:06:17 +0000 2020', text="Fucking RESTOCK Looks like I'll be at home until January 20th 2021\n#25thAmendmentNow #GOPBetrayedAmerica #Trump #TrumpLiesAmericansDie #VoteBlue #VoteBlueNoMatterWho #VoteBlue2020 #Biden2020 #TrumpOwnsEveryDeath #COVID https://t.co/IpZdoQkCge", user='LaurieWalters19', sentiment='{"pos": 0.112, "neu": 0.888, "neg": 0.0, "compound": 0.4144}'), Row(date='Sat Apr 18 22:06:18 +0000 2020', text='@realphilhendrie I find it strange that being tough on China isn’t universal. #Trump is a weakling .', user='ProHulaHooper', sentiment='{"pos": 0.0, "neu": 0.663, "neg": 0.337, "compound": -0.5574}'), Row(date='Sat Apr 18 22:06:20 +0000 2020', text='#Trump "They\'re trying to take your guns away in Virginia."\n#WhiteHousePressBriefing', user='sherylkahn', sentiment='{"pos": 0.0, "neu": 1.0, "neg": 0.0, "compound": 0.0}'), Row(date='Sat Apr 18 22:06:21 +0000 2020', text='"Mark Meadows"   TRUMP\n\nThinks Reporters asking Legit Questions of his\nLeadership failings..."Nasty"\n\nBut hookers pissing on him\nwhile spanking his butt is not~?\n\nWhat an animal~!\n#MAGA #Trump #GOP https://t.co/Rajl30euCG', user='MrAmerica', sentiment='{"pos": 0.0, "neu": 0.906, "neg": 0.094, "compound": -0.4574}'), Row(date='Sat Apr 18 22:06:21 +0000 2020', text='When you find out PLEASE let us all know! \n@realDonaldTrump', user='Tionia', sentiment='{"pos": 0.27, "neu": 0.73, "neg": 0.0, "compound": 0.5147}'), Row(date='Sat Apr 18 22:06:23 +0000 2020', text='surely we must be nearing the end of this painful farce? #Trump #TrumpPressConf #POTUS45', user='holditrightnow', sentiment='{"pos": 0.145, "neu": 0.551, "neg": 0.304, "compound": -0.4897}'), Row(date='Sat Apr 18 22:06:25 +0000 2020', text='@OregonGovBrown https://t.co/M6l5xyfSdQ\nAnd #dumbass #Trump wants to reopen the economy that will kill more Americans!', user='forcemultstevea', sentiment='{"pos": 0.0, "neu": 0.737, "neg": 0.263, "compound": -0.7177}'), Row(date='Sat Apr 18 22:06:25 +0000 2020', text='Hey, @realdonaldtrump. Go to Hell, Mr President, Sir, and do Planet Earth a big favour. Thanks. #Trump', user='67Snowy', sentiment='{"pos": 0.248, "neu": 0.556, "neg": 0.197, "compound": 0.0516}')]
# Tweet text is :  Someone is fixin' to get audited!
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  Is #Trump on his period or something???
# 🤔🤔🤔🤔🤔
# #MANopause #COVID #PressBriefing #PressConference #BreakingNews #POTUS #TrumpLiesAmericansDie #TrumpMeltdown #TrumpIsTheWORSTPresidentEVER #TrumpLiesPeopleDie https://t.co/NwJc1maVyd
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  Fucking RESTOCK Looks like I'll be at home until January 20th 2021
# #25thAmendmentNow #GOPBetrayedAmerica #Trump #TrumpLiesAmericansDie #VoteBlue #VoteBlueNoMatterWho #VoteBlue2020 #Biden2020 #TrumpOwnsEveryDeath #COVID https://t.co/IpZdoQkCge
# Overall sentiment dictionary is :  {'pos': 0.112, 'neu': 0.888, 'neg': 0.0, 'compound': 0.4144}
# sentence was rated as  0.0 % Negative
# sentence was rated as  88.8 % Neutral
# sentence was rated as  11.200000000000001 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  @realphilhendrie I find it strange that being tough on China isn’t universal. #Trump is a weakling .
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.663, 'neg': 0.337, 'compound': -0.5574}
# sentence was rated as  33.7 % Negative
# sentence was rated as  66.3 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  #Trump "They're trying to take your guns away in Virginia."
# #WhiteHousePressBriefing
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  "Mark Meadows"   TRUMP
#
# Thinks Reporters asking Legit Questions of his
# Leadership failings..."Nasty"
#
# But hookers pissing on him
# while spanking his butt is not~?
#
# What an animal~!
# #MAGA #Trump #GOP https://t.co/Rajl30euCG
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.906, 'neg': 0.094, 'compound': -0.4574}
# sentence was rated as  9.4 % Negative
# sentence was rated as  90.60000000000001 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  When you find out PLEASE let us all know!
# @realDonaldTrump
# Overall sentiment dictionary is :  {'pos': 0.27, 'neu': 0.73, 'neg': 0.0, 'compound': 0.5147}
# sentence was rated as  0.0 % Negative
# sentence was rated as  73.0 % Neutral
# sentence was rated as  27.0 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  surely we must be nearing the end of this painful farce? #Trump #TrumpPressConf #POTUS45
# Overall sentiment dictionary is :  {'pos': 0.145, 'neu': 0.551, 'neg': 0.304, 'compound': -0.4897}
# sentence was rated as  30.4 % Negative
# sentence was rated as  55.1 % Neutral
# sentence was rated as  14.499999999999998 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  @OregonGovBrown https://t.co/M6l5xyfSdQ
# And #dumbass #Trump wants to reopen the economy that will kill more Americans!
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.737, 'neg': 0.263, 'compound': -0.7177}
# sentence was rated as  26.3 % Negative
# sentence was rated as  73.7 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  Hey, @realdonaldtrump. Go to Hell, Mr President, Sir, and do Planet Earth a big favour. Thanks. #Trump
# Overall sentiment dictionary is :  {'pos': 0.248, 'neu': 0.556, 'neg': 0.197, 'compound': 0.0516}
# sentence was rated as  19.7 % Negative
# sentence was rated as  55.60000000000001 % Neutral
# sentence was rated as  24.8 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  Love when President #Trump compares the plight of Rosa Parks to the fight for Americans to keep their guns...
# #WhiteHousePressBriefing #whitehousePressconference
# Overall sentiment dictionary is :  {'pos': 0.163, 'neu': 0.736, 'neg': 0.101, 'compound': 0.3818}
# sentence was rated as  10.100000000000001 % Negative
# sentence was rated as  73.6 % Neutral
# sentence was rated as  16.3 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  @WhiteHouse @realDonaldTrump Tweets that didn't age well
#
# https://t.co/DwZxGv7RU4
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.794, 'neg': 0.206, 'compound': -0.2057}
# sentence was rated as  20.599999999999998 % Negative
# sentence was rated as  79.4 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  Modeling has hit the big time
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  Birx u SoB.. u have lost ur character &amp; integrity for an incompetent narcissist. U have blood on ur hands like #Trump.. 38k+ ppl have died bcuz of this incompetent @POTUS. @PressSec @PaulaReidCBS #AMJoy @Lawrence
# Overall sentiment dictionary is :  {'pos': 0.118, 'neu': 0.602, 'neg': 0.28, 'compound': -0.7906}
# sentence was rated as  28.000000000000004 % Negative
# sentence was rated as  60.199999999999996 % Neutral
# sentence was rated as  11.799999999999999 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  It's a fucking outright travesty that #Trump is in charge of a country like the US. Biased, incompetent, ignorant and stupid, it would appear 🥺
# Overall sentiment dictionary is :  {'pos': 0.075, 'neu': 0.482, 'neg': 0.442, 'compound': -0.9038}
# sentence was rated as  44.2 % Negative
# sentence was rated as  48.199999999999996 % Neutral
# sentence was rated as  7.5 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  If you use the word, “frankly,” you’re probably lying. #Trump
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.726, 'neg': 0.274, 'compound': -0.5267}
# sentence was rated as  27.400000000000002 % Negative
# sentence was rated as  72.6 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  @ElNoPower @realDonaldTrump How about "#Biden 2020 - he's definitely not that lying sack of 💩 #Trump."
# Overall sentiment dictionary is :  {'pos': 0.313, 'neu': 0.687, 'neg': 0.0, 'compound': 0.6679}
# sentence was rated as  0.0 % Negative
# sentence was rated as  68.7 % Neutral
# sentence was rated as  31.3 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  The economic #RESET by President #Trump is working. American companies are leaving China and returning to the USA. American #economy will soon be booming again and the world will watch with admiration.
#
# https://t.co/eUcmO0ViCQ
# Overall sentiment dictionary is :  {'pos': 0.099, 'neu': 0.901, 'neg': 0.0, 'compound': 0.5423}
# sentence was rated as  0.0 % Negative
# sentence was rated as  90.10000000000001 % Neutral
# sentence was rated as  9.9 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  Was #OANN told to ask that question before #PressBriefing  #Trump ?
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  #Trump is a dangerous idiot, and his people are dying, BUT he is kept in power by #murdoch through #foxnews. The blame rests with #murdoch
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.742, 'neg': 0.258, 'compound': -0.743}
# sentence was rated as  25.8 % Negative
# sentence was rated as  74.2 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  @realDonaldTrump @POTUS .
# #SaturdayThoughts re "#FakeNews" Sources:
#
# If the #Media Wants "Real" News They Should Contact John Barron, the "Real" Spokesman for the #FakePresident, #DonaldTrump 🤣🤣
#
# John Barron's a "Real" Source for #Trump "News"🤣🤣
#
# .https://t.co/uuqEBZ4nTT
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  Agree. But please be very careful. NO to mail in votes - ripe for fraud. Every day hammer Dems y they r apoplectic at mere mention of voter ID. #judgejeanine #Trump #coronavirus
# Overall sentiment dictionary is :  {'pos': 0.178, 'neu': 0.637, 'neg': 0.186, 'compound': -0.3222}
# sentence was rated as  18.6 % Negative
# sentence was rated as  63.7 % Neutral
# sentence was rated as  17.8 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  What does Israel have to do with social distancing in religious establishments? What does Israel have over America? Why are we talking about Israel during a pandemic? #COVID #TrumpLiesAmericansDie #trump
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  @WillieGeist @washingtonpost #Trump is a fuckwit. Winding up the people. Irresponsible. Gutless &amp; spineless. These Yanks are paranoid nut jobs. When they contract #SARS_COV_2, are hospitalised &amp; start dropping off, it'll be due to some conspiracy bullshit. Can hear their mindless ranting now #usaCoronavirus
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.717, 'neg': 0.283, 'compound': -0.9325}
# sentence was rated as  28.299999999999997 % Negative
# sentence was rated as  71.7 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  “Some of them are being unreasonable” #trump says about governors and their #socialdistancing guidelines. Again singles out Michigan and Virginia “where they’re taking their guns away” #Covid_19 #StayHome #OpeningUpAmericaAgain
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  #TrumpPressBriefing #trump says #Virginia is trying to take your guns away. THIS! from the right to life fan club. Yay for #guns. More ways to kill people. Disgusting!
# Overall sentiment dictionary is :  {'pos': 0.147, 'neu': 0.621, 'neg': 0.232, 'compound': -0.6425}
# sentence was rated as  23.200000000000003 % Negative
# sentence was rated as  62.1 % Neutral
# sentence was rated as  14.7 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  #Trump "are crazy things"
# aka
# Things that could be contagious
# #insanity
# #25AmendmentNow
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.676, 'neg': 0.324, 'compound': -0.5859}
# sentence was rated as  32.4 % Negative
# sentence was rated as  67.60000000000001 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  Just the daily reminder to #Trump that he’s running out of time to #ResignNow and get those blanket pardons from the @vp for him and his family.  🚨
#
# #TrumpIsTheWORSTPresidentEVER #TrumpCrimeFamily #TrumpPressConference
# Overall sentiment dictionary is :  {'pos': 0.071, 'neu': 0.929, 'neg': 0.0, 'compound': 0.296}
# sentence was rated as  0.0 % Negative
# sentence was rated as  92.9 % Neutral
# sentence was rated as  7.1 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  Rant about #facebook groups where the admins act like Nazis and ban your posts and then if you complain ban you...... Give people a uniform etc etc #maga #trump
# Overall sentiment dictionary is :  {'pos': 0.066, 'neu': 0.612, 'neg': 0.322, 'compound': -0.8625}
# sentence was rated as  32.2 % Negative
# sentence was rated as  61.199999999999996 % Neutral
# sentence was rated as  6.6000000000000005 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  Cleanness is the half of faith...#Trump #COVID #ihtishamnawazVines https://t.co/YJ84V5XHJ5
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  @WenMaMa2 @WhiteHouse @POTUS @realDonaldTrump @MeltingInMarana @mickelodoole @DaveSchreiber3 @JanetTXBlessed @EricJSwensson @DFBHarvard @stlpcs @KAG1776MAGA @NJ_2_FL @alexmjordan @Patti_Sc60 @dunbdav @BCMsolt @pdjf1 @ec_kag @KR_KAG @RL9631 @01ravenking @RogerFritz7 @lawlerchuck1 @DallasBrownin16 @KarenLadybug1 @elagrew @wwwillstand @Dbargen @luluHru @dyro874 @Ecomemory1 @ASweetGirlInYou @philadper2014 @Lybio @riki7s @ruby58293 @1TxStar @amicah1 @bfraser747 @BrexitLondon @JamesJdauto #magaLOVEandBlessings!
# 🦅@WenMaMa2 &amp;🙏@WhiteHouse
# 🤡TruthBeTOLD:nancyISallABOUTnancy~
# 🤑PORKINthoseBillsToSuitHerPurpose!
# ✋🏿🤚🖐🏽WEthePEOPLEareSoBLESSED
# 🙏TO HAVE:🌹🦅💪🇺🇸 @realDonaldTrump
# 🙏LEADINGtheWAYbackToA
# 🙏HEALTHY USA!
# 💪Rt’d&amp;F’dThisMIGHTYmagaTRAIN!
# 🌹ThanksWen!
# 🇺🇸#trump
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  Forgot #Trump was gonna be bloviating at 5... ish.  What'd I miss?
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.862, 'neg': 0.138, 'compound': -0.1531}
# sentence was rated as  13.8 % Negative
# sentence was rated as  86.2 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  #Trump reminds me of experiences I had as a child.
#
# ‘Better be quiet, better not interrupt
# ‘Cause you don’t know when Daddy might erupt.
# We learned our lesson from experience in the past,
# We’d better mind ourselves or Daddy’ll beat our ass.
#
# #Trump, the always mad dad.
# Overall sentiment dictionary is :  {'pos': 0.144, 'neu': 0.733, 'neg': 0.123, 'compound': 0.0351}
# sentence was rated as  12.3 % Negative
# sentence was rated as  73.3 % Neutral
# sentence was rated as  14.399999999999999 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  @OregonGovBrown Scientists find 78% of people don’t show symptoms of coronavirus — here’s what that could mean https://t.co/KImjIKSTv9
# strict social distancing measures to “flatten curve” work but when measures lifted epidemic rises again and vaccine 1 yr away ! #Trump is an idiot
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.892, 'neg': 0.108, 'compound': -0.6948}
# sentence was rated as  10.8 % Negative
# sentence was rated as  89.2 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  Here we go....#trump claiming VA trying to take your guns away.  Yeah...and there are states using this as an excuse to ban pro-choice rights. No one is coming to your house and taking your guns. #TrumpLiesAmericansDie #TrumpTemperTantrum
# Overall sentiment dictionary is :  {'pos': 0.032, 'neu': 0.827, 'neg': 0.141, 'compound': -0.6705}
# sentence was rated as  14.099999999999998 % Negative
# sentence was rated as  82.69999999999999 % Neutral
# sentence was rated as  3.2 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  Going to see more and more rioting all over the country
#
# #COVID19 #Coronavirus #USA #Trump #LasVegas #DJIA #SPY #SPX #QQQ #Lockdown
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  This isn’t the American way! @IRSnews @GregAbbott_TX @FoxNews @CNN @KENS5 @ksatnews @KABBFOX29 @News4SA #TexasStrong #Trump #SmallBusiness #barbershop
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  .@realDonaldTrump there is nothing good or honorable about you. You are a sociopath/psychopath and so are your friends. You are a parasite who uses and discards at will.  Nothing is too low for you...nothing. #Canada #London #Trump #TrumpMeltdown #TrumpPressConference .@LiarTable
# Overall sentiment dictionary is :  {'pos': 0.114, 'neu': 0.726, 'neg': 0.16, 'compound': -0.2682}
# sentence was rated as  16.0 % Negative
# sentence was rated as  72.6 % Neutral
# sentence was rated as  11.4 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  @OregonGovBrown The Math Behind Social Distancing https://t.co/FTnVJt3Rgw
# Results: when no action was taken 65% of population contracted the disease.
# But #trump doesn't understand math #covid19
# South Dakota and all red #trump states are stupid as hell!
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.759, 'neg': 0.241, 'compound': -0.8883}
# sentence was rated as  24.099999999999998 % Negative
# sentence was rated as  75.9 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  Amazing. Gave me goose bumps. #WWG1WGAWORLDWIDE
# #WWG1WGA #Trump
# https://t.co/PPZ7tsjsqd
# Overall sentiment dictionary is :  {'pos': 0.322, 'neu': 0.678, 'neg': 0.0, 'compound': 0.5859}
# sentence was rated as  0.0 % Negative
# sentence was rated as  67.80000000000001 % Neutral
# sentence was rated as  32.2 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  @BandyXLee1 #Trump mental health issue will take time to prove
#
# If the actions are illegal, the result of such actions is not legal
# #Trump is a result of the 2016 meddling
# #TrumpVirus is not legit
#
# Unlike his mental health, #fact that he is not legit is proven - #MuellerReport
#
# #Truth #Facts
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.904, 'neg': 0.096, 'compound': -0.6085}
# sentence was rated as  9.6 % Negative
# sentence was rated as  90.4 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  He said some people love Mosques..... Then he said Christian Churches have been treated unfairly as if there are Muslim Churches or Buddhist Churches?  #Jesustakethewheel #Trump #WhiteHouseBriefing #altleft  #WhiteHousePressBriefing #Covid19
# Overall sentiment dictionary is :  {'pos': 0.127, 'neu': 0.873, 'neg': 0.0, 'compound': 0.6369}
# sentence was rated as  0.0 % Negative
# sentence was rated as  87.3 % Neutral
# sentence was rated as  12.7 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  AbsoFUCKINGlutely. I Fuckety, Fuck agree.
# Overall sentiment dictionary is :  {'pos': 0.312, 'neu': 0.25, 'neg': 0.438, 'compound': -0.25}
# sentence was rated as  43.8 % Negative
# sentence was rated as  25.0 % Neutral
# sentence was rated as  31.2 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  The man is unfit to serve. A national and global embarrassment. 💔🇺🇸😷 https://t.co/KbEqiBAo0U
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.791, 'neg': 0.209, 'compound': -0.4404}
# sentence was rated as  20.9 % Negative
# sentence was rated as  79.10000000000001 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  The prophecy of Donald Trump. A must watch! In fact, go watch all his videos!
# https://t.co/IeIAWDZlvg
#
# #Trump #DrainTheSwamp
# #Trump2020 #QAnon2020
# #endoftheworld #qarmy #OccupyDemocrats
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  @Dvscott81Scott @Derameth @realRyanPence @Trumpism0 @PatriotToolbox @beyond_reesons @Courage_Mill @gregallen1959 @Signalm22227203 @gd49er @pvvult @mollyday15 @Lybio @cuban_manny @Preciouslindy @DRH1959 @RedWolfe45 @TimMc777 @WonderYNTexas @Dvscott81Scott I LOVE YOUR MEME! I jumped on the train just because of it! You Rock 🇺🇸 and #Trump 🔲 is My President AMEN ✝️ @coco_deech 🌟 IFAPB
# Overall sentiment dictionary is :  {'pos': 0.116, 'neu': 0.884, 'neg': 0.0, 'compound': 0.7592}
# sentence was rated as  0.0 % Negative
# sentence was rated as  88.4 % Neutral
# sentence was rated as  11.600000000000001 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  #OANN "reporter" just described Pelosi as "dragging her feet" on approving new funding. If a real reporter used similar words regarding Republicans #Trump would stomp his feet and throw a hissy fit. #WhiteHousePressBriefing #Covid_19
# Overall sentiment dictionary is :  {'pos': 0.075, 'neu': 0.925, 'neg': 0.0, 'compound': 0.3612}
# sentence was rated as  0.0 % Negative
# sentence was rated as  92.5 % Neutral
# sentence was rated as  7.5 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  #Trump planted question now about @SpeakerPelosi, as @realDonaldTrump tries to get more Blank Checks to give to #Trump supporters....
#
# And now #Birx has lost our faith as she defends Open Beaches in Florida....
#
# #Trump is DILLUSIONAL!
# Overall sentiment dictionary is :  {'pos': 0.078, 'neu': 0.863, 'neg': 0.058, 'compound': 0.2003}
# sentence was rated as  5.800000000000001 % Negative
# sentence was rated as  86.3 % Neutral
# sentence was rated as  7.8 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  @CNN
# @MSNBC
# Please stop covering this craziness.
# He’s just confusing us!
# #Trump is nutty as a fruitcake!
# He’s a very small man with a huge amount of power!
# He’s saying crazy things!
# Virginia wants to take our guns away!
# He’s the President and he’s saying this!
# #TrumpMeltdown
# Overall sentiment dictionary is :  {'pos': 0.087, 'neu': 0.719, 'neg': 0.194, 'compound': -0.6876}
# sentence was rated as  19.400000000000002 % Negative
# sentence was rated as  71.89999999999999 % Neutral
# sentence was rated as  8.7 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  “Some people are fishing...they’re arresting people. That’s ridiculous...we have a lot of people that don’t have to be told to do anything.” -@POTUS
#
# The government exists to PROTECT, not to INFRINGE on our rights.
# #COVID #Trump #maga #kag #Constitution #COVIDIOTS
# Overall sentiment dictionary is :  {'pos': 0.081, 'neu': 0.919, 'neg': 0.0, 'compound': 0.516}
# sentence was rated as  0.0 % Negative
# sentence was rated as  91.9 % Neutral
# sentence was rated as  8.1 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  "National security advisers #warned #Trump about the virus’s expected spread through the country in #early #January, shortly after cases began spreading in
# #China. As weeks ticked by, #Trump #minimized the problem in his #messaging, did little to address #testing #shortages, and
# Overall sentiment dictionary is :  {'pos': 0.052, 'neu': 0.828, 'neg': 0.12, 'compound': -0.4767}
# sentence was rated as  12.0 % Negative
# sentence was rated as  82.8 % Neutral
# sentence was rated as  5.2 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  “Sitting in a boat in a lake should be OK,” counsels #Trump. “Governors have gotten carried away,” doing what said he want yesterday.
# Mommy I’m dizzy 😵
# #TrumpPressConference #CoronavirusUSA #MSNBC
# Overall sentiment dictionary is :  {'pos': 0.046, 'neu': 0.887, 'neg': 0.067, 'compound': -0.1531}
# sentence was rated as  6.7 % Negative
# sentence was rated as  88.7 % Neutral
# sentence was rated as  4.6 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  I'm I the only one screaming at the TV 1918 not 1917? Looks like I'll be at home until January 20th 2021
# #25thAmendmentNow #GOPBetrayedAmerica #Trump #TrumpLiesAmericansDie #VoteBlue #VoteBlueNoMatterWho #VoteBlue2020 #Biden2020 #TrumpOwnsEveryDeath #COVID https://t.co/oVbZgFfoua
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.864, 'neg': 0.136, 'compound': -0.5733}
# sentence was rated as  13.600000000000001 % Negative
# sentence was rated as  86.4 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# after sentiment and before push to elastice search:  [{'date': datetime.datetime(2020, 4, 18, 22, 6, 15, tzinfo=datetime.timezone.utc), 'text': "Someone is fixin' to get audited!", 'user': 'agargmd', 'sentiment': {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}, 'negative_pecentage': '0.00', 'neutral_percentage': '100.00', 'positive_percentage': '0.00', 'sentiment_type': 'neutral'}, {'date': datetime.datetime(2020, 4, 18, 22, 6, 15, tzinfo=datetime.timezone.utc), 'text': 'Is #Trump on his period or something???\n🤔🤔🤔🤔🤔\n#MANopause #COVID #PressBriefing #PressConference #BreakingNews #POTUS #TrumpLiesAmericansDie #TrumpMeltdown #TrumpIsTheWORSTPresidentEVER #TrumpLiesPeopleDie https://t.co/NwJc1maVyd', 'user': 'mmtexas', 'sentiment': {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}, 'negative_pecentage': '0.00', 'neutral_percentage': '100.00', 'positive_percentage': '0.00', 'sentiment_type': 'neutral'}, {'date': datetime.datetime(2020, 4, 18, 22, 6, 17, tzinfo=datetime.timezone.utc), 'text': "Fucking RESTOCK Looks like I'll be at home until January 20th 2021\n#25thAmendmentNow #GOPBetrayedAmerica #Trump #TrumpLiesAmericansDie #VoteBlue #VoteBlueNoMatterWho #VoteBlue2020 #Biden2020 #TrumpOwnsEveryDeath #COVID https://t.co/IpZdoQkCge", 'user': 'LaurieWalters19', 'sentiment': {'pos': 0.112, 'neu': 0.888, 'neg': 0.0, 'compound': 0.4144}, 'negative_pecentage': '0.00', 'neutral_percentage': '88.80', 'positive_percentage': '11.20', 'sentiment_type': 'positive'}, {'date': datetime.datetime(2020, 4, 18, 22, 6, 18, tzinfo=datetime.timezone.utc), 'text': '@realphilhendrie I find it strange that being tough on China isn’t universal. #Trump is a weakling .', 'user': 'ProHulaHooper', 'sentiment': {'pos': 0.0, 'neu': 0.663, 'neg': 0.337, 'compound': -0.5574}, 'negative_pecentage': '33.70', 'neutral_percentage': '66.30', 'positive_percentage': '0.00', 'sentiment_type': 'negative'}, {'date': datetime.datetime(2020, 4, 18, 22, 6, 20, tzinfo=datetime.timezone.utc), 'text': '#Trump "They\'re trying to take your guns away in Virginia."\n#WhiteHousePressBriefing', 'user': 'sherylkahn', 'sentiment': {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}, 'negative_pecentage': '0.00', 'neutral_percentage': '100.00', 'positive_percentage': '0.00', 'sentiment_type': 'neutral'}, {'date': datetime.datetime(2020, 4, 18, 22, 6, 21, tzinfo=datetime.timezone.utc), 'text': '"Mark Meadows"   TRUMP\n\nThinks Reporters asking Legit Questions of his\nLeadership failings..."Nasty"\n\nBut hookers pissing on him\nwhile spanking his butt is not~?\n\nWhat an animal~!\n#MAGA #Trump #GOP https://t.co/Rajl30euCG', 'user': 'MrAmerica', 'sentiment': {'pos': 0.0, 'neu': 0.906, 'neg': 0.094, 'compound': -0.4574}, 'negative_pecentage': '9.40', 'neutral_percentage': '90.60', 'positive_percentage': '0.00', 'sentiment_type': 'negative'}, {'date': datetime.datetime(2020, 4, 18, 22, 6, 21, tzinfo=datetime.timezone.utc), 'text': 'When you find out PLEASE let us all know! \n@realDonaldTrump', 'user': 'Tionia', 'sentiment': {'pos': 0.27, 'neu': 0.73, 'neg': 0.0, 'compound': 0.5147}, 'negative_pecentage': '0.00', 'neutral_percentage': '73.00', 'positive_percentage': '27.00', 'sentiment_type': 'positive'}, {'date': datetime.datetime(2020, 4, 18, 22, 6, 23, tzinfo=datetime.timezone.utc), 'text': 'surely we must be nearing the end of this painful farce? #Trump #TrumpPressConf #POTUS45', 'user': 'holditrightnow', 'sentiment': {'pos': 0.145, 'neu': 0.551, 'neg': 0.304, 'compound': -0.4897}, 'negative_pecentage': '30.40', 'neutral_percentage': '55.10', 'positive_percentage': '14.50', 'sentiment_type': 'negative'}, {'date': datetime.datetime(2020, 4, 18, 22, 6, 25, tzinfo=datetime.timezone.utc), 'text': '@OregonGovBrown https://t.co/M6l5xyfSdQ\nAnd #dumbass #Trump wants to reopen the economy that will kill more Americans!', 'user': 'forcemultstevea', 'sentiment': {'pos': 0.0, 'neu': 0.737, 'neg': 0.263, 'compound': -0.7177}, 'negative_pecentage': '26.30', 'neutral_percentage': '73.70' ...
# ========= 2020-04-18 17:07:40 =========
# [Row(date='Sat Apr 18 22:07:31 +0000 2020', text='@AngrierWHStaff From parks in Texas, to the steps at the Capitol in Michigan to the beaches of Jacksonville Florida...he is trying cause civil riots throughout the United States because #Trump knows he WON’T be re-elected #TrumpIsTheWORSTPresidentEVER', user='gkgguy'), Row(date='Sat Apr 18 22:07:32 +0000 2020', text='Is it time to sit down with my 20 year old son and have a serious, terrifying discussion about how #Trump is trying to kill all of us? \n\nNot joking.', user='LynSonyaA'), Row(date='Sat Apr 18 22:07:34 +0000 2020', text='#WHO IS #CHINA FRIENDLY! AND HATES #USA. BLAME #FUCKINGCHINA FOR THIS VIRUS AND NOT #UnitedStatesOfAmerica NOR #TRUMP. SHIT CAUSED BY CHINA AND THEY KILLED SO MANY PEOPLE. #CHINESE LIED AND COVERED THIS SHIT AND CAUSED A HUGE PROBLEM. ITS WAS FUCKING CHINA!!!!!!', user='Martin25150073')]
# after sentiment: [Row(date='Sat Apr 18 22:07:31 +0000 2020', text='@AngrierWHStaff From parks in Texas, to the steps at the Capitol in Michigan to the beaches of Jacksonville Florida...he is trying cause civil riots throughout the United States because #Trump knows he WON’T be re-elected #TrumpIsTheWORSTPresidentEVER', user='gkgguy', sentiment='{"pos": 0.07, "neu": 0.848, "neg": 0.082, "compound": -0.128}'), Row(date='Sat Apr 18 22:07:32 +0000 2020', text='Is it time to sit down with my 20 year old son and have a serious, terrifying discussion about how #Trump is trying to kill all of us? \n\nNot joking.', user='LynSonyaA', sentiment='{"pos": 0.0, "neu": 0.687, "neg": 0.313, "compound": -0.8851}'), Row(date='Sat Apr 18 22:07:34 +0000 2020', text='#WHO IS #CHINA FRIENDLY! AND HATES #USA. BLAME #FUCKINGCHINA FOR THIS VIRUS AND NOT #UnitedStatesOfAmerica NOR #TRUMP. SHIT CAUSED BY CHINA AND THEY KILLED SO MANY PEOPLE. #CHINESE LIED AND COVERED THIS SHIT AND CAUSED A HUGE PROBLEM. ITS WAS FUCKING CHINA!!!!!!', user='Martin25150073', sentiment='{"pos": 0.211, "neu": 0.486, "neg": 0.303, "compound": -0.7926}')]
# Tweet text is :  @AngrierWHStaff From parks in Texas, to the steps at the Capitol in Michigan to the beaches of Jacksonville Florida...he is trying cause civil riots throughout the United States because #Trump knows he WON’T be re-elected #TrumpIsTheWORSTPresidentEVER
# Overall sentiment dictionary is :  {'pos': 0.07, 'neu': 0.848, 'neg': 0.082, 'compound': -0.128}
# sentence was rated as  8.200000000000001 % Negative
# sentence was rated as  84.8 % Neutral
# sentence was rated as  7.000000000000001 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  Is it time to sit down with my 20 year old son and have a serious, terrifying discussion about how #Trump is trying to kill all of us?
#
# Not joking.
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.687, 'neg': 0.313, 'compound': -0.8851}
# sentence was rated as  31.3 % Negative
# sentence was rated as  68.7 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  #WHO IS #CHINA FRIENDLY! AND HATES #USA. BLAME #FUCKINGCHINA FOR THIS VIRUS AND NOT #UnitedStatesOfAmerica NOR #TRUMP. SHIT CAUSED BY CHINA AND THEY KILLED SO MANY PEOPLE. #CHINESE LIED AND COVERED THIS SHIT AND CAUSED A HUGE PROBLEM. ITS WAS FUCKING CHINA!!!!!!
# Overall sentiment dictionary is :  {'pos': 0.211, 'neu': 0.486, 'neg': 0.303, 'compound': -0.7926}
# sentence was rated as  30.3 % Negative
# sentence was rated as  48.6 % Neutral
# sentence was rated as  21.099999999999998 % Positive
# Negative
# old cal NEGATIVE
# after sentiment and before push to elastice search:  [{'date': datetime.datetime(2020, 4, 18, 22, 7, 31, tzinfo=datetime.timezone.utc), 'text': '@AngrierWHStaff From parks in Texas, to the steps at the Capitol in Michigan to the beaches of Jacksonville Florida...he is trying cause civil riots throughout the United States because #Trump knows he WON’T be re-elected #TrumpIsTheWORSTPresidentEVER', 'user': 'gkgguy', 'sentiment': {'pos': 0.07, 'neu': 0.848, 'neg': 0.082, 'compound': -0.128}, 'negative_pecentage': '8.20', 'neutral_percentage': '84.80', 'positive_percentage': '7.00', 'sentiment_type': 'negative'}, {'date': datetime.datetime(2020, 4, 18, 22, 7, 32, tzinfo=datetime.timezone.utc), 'text': 'Is it time to sit down with my 20 year old son and have a serious, terrifying discussion about how #Trump is trying to kill all of us? \n\nNot joking.', 'user': 'LynSonyaA', 'sentiment': {'pos': 0.0, 'neu': 0.687, 'neg': 0.313, 'compound': -0.8851}, 'negative_pecentage': '31.30', 'neutral_percentage': '68.70', 'positive_percentage': '0.00', 'sentiment_type': 'negative'}, {'date': datetime.datetime(2020, 4, 18, 22, 7, 34, tzinfo=datetime.timezone.utc), 'text': '#WHO IS #CHINA FRIENDLY! AND HATES #USA. BLAME #FUCKINGCHINA FOR THIS VIRUS AND NOT #UnitedStatesOfAmerica NOR #TRUMP. SHIT CAUSED BY CHINA AND THEY KILLED SO MANY PEOPLE. #CHINESE LIED AND COVERED THIS SHIT AND CAUSED A HUGE PROBLEM. ITS WAS FUCKING CHINA!!!!!!', 'user': 'Martin25150073', 'sentiment': {'pos': 0.211, 'neu': 0.486, 'neg': 0.303, 'compound': -0.7926}, 'negative_pecentage': '30.30', 'neutral_percentage': '48.60', 'positive_percentage': '21.10', 'sentiment_type': 'negative'}]
# ========= 2020-04-18 17:07:50 =========
# [Row(date='Sat Apr 18 22:07:40 +0000 2020', text='#Trump kills. #FireTrump', user='ENG1375'), Row(date='Sat Apr 18 22:07:41 +0000 2020', text='#Trump press conference', user='Simo10_10'), Row(date='Sat Apr 18 22:07:42 +0000 2020', text='Second amendment is "liberty.\' - #Trump #TrumpPressConf', user='thmgen11')]
# after sentiment: [Row(date='Sat Apr 18 22:07:40 +0000 2020', text='#Trump kills. #FireTrump', user='ENG1375', sentiment='{"pos": 0.0, "neu": 0.364, "neg": 0.636, "compound": -0.5423}'), Row(date='Sat Apr 18 22:07:41 +0000 2020', text='#Trump press conference', user='Simo10_10', sentiment='{"pos": 0.0, "neu": 1.0, "neg": 0.0, "compound": 0.0}'), Row(date='Sat Apr 18 22:07:42 +0000 2020', text='Second amendment is "liberty.\' - #Trump #TrumpPressConf', user='thmgen11', sentiment='{"pos": 0.0, "neu": 1.0, "neg": 0.0, "compound": 0.0}')]
# Tweet text is :  #Trump kills. #FireTrump
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.364, 'neg': 0.636, 'compound': -0.5423}
# sentence was rated as  63.6 % Negative
# sentence was rated as  36.4 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  #Trump press conference
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  Second amendment is "liberty.' - #Trump #TrumpPressConf
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# after sentiment and before push to elastice search:  [{'date': datetime.datetime(2020, 4, 18, 22, 7, 40, tzinfo=datetime.timezone.utc), 'text': '#Trump kills. #FireTrump', 'user': 'ENG1375', 'sentiment': {'pos': 0.0, 'neu': 0.364, 'neg': 0.636, 'compound': -0.5423}, 'negative_pecentage': '63.60', 'neutral_percentage': '36.40', 'positive_percentage': '0.00', 'sentiment_type': 'negative'}, {'date': datetime.datetime(2020, 4, 18, 22, 7, 41, tzinfo=datetime.timezone.utc), 'text': '#Trump press conference', 'user': 'Simo10_10', 'sentiment': {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}, 'negative_pecentage': '0.00', 'neutral_percentage': '100.00', 'positive_percentage': '0.00', 'sentiment_type': 'neutral'}, {'date': datetime.datetime(2020, 4, 18, 22, 7, 42, tzinfo=datetime.timezone.utc), 'text': 'Second amendment is "liberty.\' - #Trump #TrumpPressConf', 'user': 'thmgen11', 'sentiment': {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}, 'negative_pecentage': '0.00', 'neutral_percentage': '100.00', 'positive_percentage': '0.00', 'sentiment_type': 'neutral'}]
# ========= 2020-04-18 17:08:00 =========
# [Row(date='Sat Apr 18 22:07:46 +0000 2020', text='@JoeBiden Have you been sleeping?#COVID #Trump', user='wordsaretools'), Row(date='Sat Apr 18 22:07:48 +0000 2020', text="Comment: 04182020\n#Trump suggests wrongfully the US deaths fr #COVID19 will be 60k. It's to early to tell the 60k is on the premiss of high mitigation measures and follow up by the public. Lessening the mitigation will raise the R0 with many more people infected, more deaths.", user='PHD2468'), Row(date='Sat Apr 18 22:07:49 +0000 2020', text='"The democrats are trying to take the 2nd amendment away" - Uh.....no, not really...... This very much feels like his attempt at restarting the civil war to distract from his failures around the handling of COVID.  #Trump #TrumpPressConf', user='realhumanpotato')]
# after sentiment: [Row(date='Sat Apr 18 22:07:46 +0000 2020', text='@JoeBiden Have you been sleeping?#COVID #Trump', user='wordsaretools', sentiment='{"pos": 0.0, "neu": 1.0, "neg": 0.0, "compound": 0.0}'), Row(date='Sat Apr 18 22:07:48 +0000 2020', text="Comment: 04182020\n#Trump suggests wrongfully the US deaths fr #COVID19 will be 60k. It's to early to tell the 60k is on the premiss of high mitigation measures and follow up by the public. Lessening the mitigation will raise the R0 with many more people infected, more deaths.", user='PHD2468', sentiment='{"pos": 0.0, "neu": 0.931, "neg": 0.069, "compound": -0.539}'), Row(date='Sat Apr 18 22:07:49 +0000 2020', text='"The democrats are trying to take the 2nd amendment away" - Uh.....no, not really...... This very much feels like his attempt at restarting the civil war to distract from his failures around the handling of COVID.  #Trump #TrumpPressConf', user='realhumanpotato', sentiment='{"pos": 0.062, "neu": 0.736, "neg": 0.203, "compound": -0.7458}')]
# Tweet text is :  @JoeBiden Have you been sleeping?#COVID #Trump
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  Comment: 04182020
# #Trump suggests wrongfully the US deaths fr #COVID19 will be 60k. It's to early to tell the 60k is on the premiss of high mitigation measures and follow up by the public. Lessening the mitigation will raise the R0 with many more people infected, more deaths.
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.931, 'neg': 0.069, 'compound': -0.539}
# sentence was rated as  6.9 % Negative
# sentence was rated as  93.10000000000001 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  "The democrats are trying to take the 2nd amendment away" - Uh.....no, not really...... This very much feels like his attempt at restarting the civil war to distract from his failures around the handling of COVID.  #Trump #TrumpPressConf
# Overall sentiment dictionary is :  {'pos': 0.062, 'neu': 0.736, 'neg': 0.203, 'compound': -0.7458}
# sentence was rated as  20.3 % Negative
# sentence was rated as  73.6 % Neutral
# sentence was rated as  6.2 % Positive
# Negative
# old cal NEGATIVE
# after sentiment and before push to elastice search:  [{'date': datetime.datetime(2020, 4, 18, 22, 7, 46, tzinfo=datetime.timezone.utc), 'text': '@JoeBiden Have you been sleeping?#COVID #Trump', 'user': 'wordsaretools', 'sentiment': {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}, 'negative_pecentage': '0.00', 'neutral_percentage': '100.00', 'positive_percentage': '0.00', 'sentiment_type': 'neutral'}, {'date': datetime.datetime(2020, 4, 18, 22, 7, 48, tzinfo=datetime.timezone.utc), 'text': "Comment: 04182020\n#Trump suggests wrongfully the US deaths fr #COVID19 will be 60k. It's to early to tell the 60k is on the premiss of high mitigation measures and follow up by the public. Lessening the mitigation will raise the R0 with many more people infected, more deaths.", 'user': 'PHD2468', 'sentiment': {'pos': 0.0, 'neu': 0.931, 'neg': 0.069, 'compound': -0.539}, 'negative_pecentage': '6.90', 'neutral_percentage': '93.10', 'positive_percentage': '0.00', 'sentiment_type': 'negative'}, {'date': datetime.datetime(2020, 4, 18, 22, 7, 49, tzinfo=datetime.timezone.utc), 'text': '"The democrats are trying to take the 2nd amendment away" - Uh.....no, not really...... This very much feels like his attempt at restarting the civil war to distract from his failures around the handling of COVID.  #Trump #TrumpPressConf', 'user': 'realhumanpotato', 'sentiment': {'pos': 0.062, 'neu': 0.736, 'neg': 0.203, 'compound': -0.7458}, 'negative_pecentage': '20.30', 'neutral_percentage': '73.60', 'positive_percentage': '6.20', 'sentiment_type': 'negative'}]
# ========= 2020-04-18 17:08:10 =========
# ...
# ========= 2020-04-18 17:08:20 =========
# [Row(date='Sat Apr 18 22:08:06 +0000 2020', text='@paulsperry_ @realDonaldTrump WRONG!! #Trump just started the spikes again by encouraging his people to openly ignoring the social distancing rules. These fools will cause another outbreaks, continue to tank the economy and endanger the healthcare professionals #TrumpLiesAmericansDie . https://t.co/SODqpYDItJ', user='PamTeaTea'), Row(date='Sat Apr 18 22:08:06 +0000 2020', text='@MrsAmerica2020 @Breaking911 Any system breeds tyranny if the necessary megalomaniac is in power. Cf. #Trump and his push for #FascistGOP rather than simply the conservatives previously in charge of the party. \n\nBut guessing you as operator of a fake account may already know that. https://t.co/dku5AIYzaa', user='tejaswoman'), Row(date='Sat Apr 18 22:08:07 +0000 2020', text='The Divider in chief president #Trump.', user='thaha_sherwani'), Row(date='Sat Apr 18 22:08:08 +0000 2020', text="'Ask not what your country can do for you, ask what you can do for your country' JFK\n\n'Only thing we have to fear is fear itself' FDR\n\n'I believe someone, sitting in a boat. In a lake. Should be OK.' The Cheeto. #Trump", user='milominder'), Row(date='Sat Apr 18 22:08:10 +0000 2020', text='@ratherbinmaui He obviously is "proud" of Deaths/1M Pop. For sure not because, but despite of #Trump that number seems to be not that high. https://t.co/fNW9rzFnqj', user='cehaka'), Row(date='Sat Apr 18 22:08:11 +0000 2020', text='Rosa Parks Drumpf thinks Rosa Parks is where the Cincinnati Reds play their home games. #DumpTrump2020 #TrumpMeltdown #trump #VoteBlueNoMatterWho #VoteBlue', user='Buzzporter'), Row(date='Sat Apr 18 22:08:12 +0000 2020', text='#Trump, YOU LIE!!!!! #Resist', user='EltonJane'), Row(date='Sat Apr 18 22:08:12 +0000 2020', text='After my lovely hour with @GovAndyBeshear, for shits and grins I turned over to #Trump. It took 20 seconds for me to switch over to @hgtv.', user='FatRatWithIron'), Row(date='Sat Apr 18 22:08:14 +0000 2020', text='What does guns have to do with #CoronavirusUSA and 6 feet safety factor? #Trump again straddling the fence again, the other side are good people too.', user='LonnieJameslee')]
# after sentiment: [Row(date='Sat Apr 18 22:08:06 +0000 2020', text='@paulsperry_ @realDonaldTrump WRONG!! #Trump just started the spikes again by encouraging his people to openly ignoring the social distancing rules. These fools will cause another outbreaks, continue to tank the economy and endanger the healthcare professionals #TrumpLiesAmericansDie . https://t.co/SODqpYDItJ', user='PamTeaTea', sentiment='{"pos": 0.071, "neu": 0.713, "neg": 0.216, "compound": -0.7856}'), Row(date='Sat Apr 18 22:08:06 +0000 2020', text='@MrsAmerica2020 @Breaking911 Any system breeds tyranny if the necessary megalomaniac is in power. Cf. #Trump and his push for #FascistGOP rather than simply the conservatives previously in charge of the party. \n\nBut guessing you as operator of a fake account may already know that. https://t.co/dku5AIYzaa', user='tejaswoman', sentiment='{"pos": 0.056, "neu": 0.879, "neg": 0.065, "compound": -0.1027}'), Row(date='Sat Apr 18 22:08:07 +0000 2020', text='The Divider in chief president #Trump.', user='thaha_sherwani', sentiment='{"pos": 0.0, "neu": 1.0, "neg": 0.0, "compound": 0.0}'), Row(date='Sat Apr 18 22:08:08 +0000 2020', text="'Ask not what your country can do for you, ask what you can do for your country' JFK\n\n'Only thing we have to fear is fear itself' FDR\n\n'I believe someone, sitting in a boat. In a lake. Should be OK.' The Cheeto. #Trump", user='milominder', sentiment='{"pos": 0.0, "neu": 0.862, "neg": 0.138, "compound": -0.7506}'), Row(date='Sat Apr 18 22:08:10 +0000 2020', text='@ratherbinmaui He obviously is "proud" of Deaths/1M Pop. For sure not because, but despite of #Trump that number seems to be not that high. https://t.co/fNW9rzFnqj', user='cehaka', sentiment='{"pos": 0.119, "neu": 0.881, "neg": 0.0, "compound": 0.2732}'), Row(date='Sat Apr 18 22:08:11 +0000 2020', text='Rosa Parks Drumpf thinks Rosa Parks is where the Cincinnati Reds play their home games. #DumpTrump2020 #TrumpMeltdown #trump #VoteBlueNoMatterWho #VoteBlue', user='Buzzporter', sentiment='{"pos": 0.112, "neu": 0.888, "neg": 0.0, "compound": 0.34}'), Row(date='Sat Apr 18 22:08:12 +0000 2020', text='#Trump, YOU LIE!!!!! #Resist', user='EltonJane', sentiment='{"pos": 0.0, "neu": 1.0, "neg": 0.0, "compound": 0.0}'), Row(date='Sat Apr 18 22:08:12 +0000 2020', text='After my lovely hour with @GovAndyBeshear, for shits and grins I turned over to #Trump. It took 20 seconds for me to switch over to @hgtv.', user='FatRatWithIron', sentiment='{"pos": 0.185, "neu": 0.714, "neg": 0.101, "compound": 0.3818}'), Row(date='Sat Apr 18 22:08:14 +0000 2020', text='What does guns have to do with #CoronavirusUSA and 6 feet safety factor? #Trump again straddling the fence again, the other side are good people too.', user='LonnieJameslee', sentiment='{"pos": 0.199, "neu": 0.801, "neg": 0.0, "compound": 0.6908}')]
# Tweet text is :  @paulsperry_ @realDonaldTrump WRONG!! #Trump just started the spikes again by encouraging his people to openly ignoring the social distancing rules. These fools will cause another outbreaks, continue to tank the economy and endanger the healthcare professionals #TrumpLiesAmericansDie . https://t.co/SODqpYDItJ
# Overall sentiment dictionary is :  {'pos': 0.071, 'neu': 0.713, 'neg': 0.216, 'compound': -0.7856}
# sentence was rated as  21.6 % Negative
# sentence was rated as  71.3 % Neutral
# sentence was rated as  7.1 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  @MrsAmerica2020 @Breaking911 Any system breeds tyranny if the necessary megalomaniac is in power. Cf. #Trump and his push for #FascistGOP rather than simply the conservatives previously in charge of the party.
#
# But guessing you as operator of a fake account may already know that. https://t.co/dku5AIYzaa
# Overall sentiment dictionary is :  {'pos': 0.056, 'neu': 0.879, 'neg': 0.065, 'compound': -0.1027}
# sentence was rated as  6.5 % Negative
# sentence was rated as  87.9 % Neutral
# sentence was rated as  5.6000000000000005 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  The Divider in chief president #Trump.
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  'Ask not what your country can do for you, ask what you can do for your country' JFK
#
# 'Only thing we have to fear is fear itself' FDR
#
# 'I believe someone, sitting in a boat. In a lake. Should be OK.' The Cheeto. #Trump
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 0.862, 'neg': 0.138, 'compound': -0.7506}
# sentence was rated as  13.8 % Negative
# sentence was rated as  86.2 % Neutral
# sentence was rated as  0.0 % Positive
# Negative
# old cal NEGATIVE
# Tweet text is :  @ratherbinmaui He obviously is "proud" of Deaths/1M Pop. For sure not because, but despite of #Trump that number seems to be not that high. https://t.co/fNW9rzFnqj
# Overall sentiment dictionary is :  {'pos': 0.119, 'neu': 0.881, 'neg': 0.0, 'compound': 0.2732}
# sentence was rated as  0.0 % Negative
# sentence was rated as  88.1 % Neutral
# sentence was rated as  11.899999999999999 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  Rosa Parks Drumpf thinks Rosa Parks is where the Cincinnati Reds play their home games. #DumpTrump2020 #TrumpMeltdown #trump #VoteBlueNoMatterWho #VoteBlue
# Overall sentiment dictionary is :  {'pos': 0.112, 'neu': 0.888, 'neg': 0.0, 'compound': 0.34}
# sentence was rated as  0.0 % Negative
# sentence was rated as  88.8 % Neutral
# sentence was rated as  11.200000000000001 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  #Trump, YOU LIE!!!!! #Resist
# Overall sentiment dictionary is :  {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Neutral
# old cal NEUTRAL
# Tweet text is :  After my lovely hour with @GovAndyBeshear, for shits and grins I turned over to #Trump. It took 20 seconds for me to switch over to @hgtv.
# Overall sentiment dictionary is :  {'pos': 0.185, 'neu': 0.714, 'neg': 0.101, 'compound': 0.3818}
# sentence was rated as  10.100000000000001 % Negative
# sentence was rated as  71.39999999999999 % Neutral
# sentence was rated as  18.5 % Positive
# Positive
# old cal POSITIVE
# Tweet text is :  What does guns have to do with #CoronavirusUSA and 6 feet safety factor? #Trump again straddling the fence again, the other side are good people too.
# Overall sentiment dictionary is :  {'pos': 0.199, 'neu': 0.801, 'neg': 0.0, 'compound': 0.6908}
# sentence was rated as  0.0 % Negative
# sentence was rated as  80.10000000000001 % Neutral
# sentence was rated as  19.900000000000002 % Positive
# Positive
# old cal POSITIVE
# after sentiment and before push to elastice search:  [{'date': datetime.datetime(2020, 4, 18, 22, 8, 6, tzinfo=datetime.timezone.utc), 'text': '@paulsperry_ @realDonaldTrump WRONG!! #Trump just started the spikes again by encouraging his people to openly ignoring the social distancing rules. These fools will cause another outbreaks, continue to tank the economy and endanger the healthcare professionals #TrumpLiesAmericansDie . https://t.co/SODqpYDItJ', 'user': 'PamTeaTea', 'sentiment': {'pos': 0.071, 'neu': 0.713, 'neg': 0.216, 'compound': -0.7856}, 'negative_pecentage': '21.60', 'neutral_percentage': '71.30', 'positive_percentage': '7.10', 'sentiment_type': 'negative'}, {'date': datetime.datetime(2020, 4, 18, 22, 8, 6, tzinfo=datetime.timezone.utc), 'text': '@MrsAmerica2020 @Breaking911 Any system breeds tyranny if the necessary megalomaniac is in power. Cf. #Trump and his push for #FascistGOP rather than simply the conservatives previously in charge of the party. \n\nBut guessing you as operator of a fake account may already know that. https://t.co/dku5AIYzaa', 'user': 'tejaswoman', 'sentiment': {'pos': 0.056, 'neu': 0.879, 'neg': 0.065, 'compound': -0.1027}, 'negative_pecentage': '6.50', 'neutral_percentage': '87.90', 'positive_percentage': '5.60', 'sentiment_type': 'negative'}, {'date': datetime.datetime(2020, 4, 18, 22, 8, 7, tzinfo=datetime.timezone.utc), 'text': 'The Divider in chief president #Trump.', 'user': 'thaha_sherwani', 'sentiment': {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}, 'negative_pecentage': '0.00', 'neutral_percentage': '100.00', 'positive_percentage': '0.00', 'sentiment_type': 'neutral'}, {'date': datetime.datetime(2020, 4, 18, 22, 8, 8, tzinfo=datetime.timezone.utc), 'text': "'Ask not what your country can do for you, ask what you can do for your country' JFK\n\n'Only thing we have to fear is fear itself' FDR\n\n'I believe someone, sitting in a boat. In a lake. Should be OK.' The Cheeto. #Trump", 'user': 'milominder', 'sentiment': {'pos': 0.0, 'neu': 0.862, 'neg': 0.138, 'compound': -0.7506}, 'negative_pecentage': '13.80', 'neutral_percentage': '86.20', 'positive_percentage': '0.00', 'sentiment_type': 'negative'}, {'date': datetime.datetime(2020, 4, 18, 22, 8, 10, tzinfo=datetime.timezone.utc), 'text': '@ratherbinmaui He obviously is "proud" of Deaths/1M Pop. For sure not because, but despite of #Trump that number seems to be not that high. https://t.co/fNW9rzFnqj', 'user': 'cehaka', 'sentiment': {'pos': 0.119, 'neu': 0.881, 'neg': 0.0, 'compound': 0.2732}, 'negative_pecentage': '0.00', 'neutral_percentage': '88.10', 'positive_percentage': '11.90', 'sentiment_type': 'positive'}, {'date': datetime.datetime(2020, 4, 18, 22, 8, 11, tzinfo=datetime.timezone.utc), 'text': 'Rosa Parks Drumpf thinks Rosa Parks is where the Cincinnati Reds play their home games. #DumpTrump2020 #TrumpMeltdown #trump #VoteBlueNoMatterWho #VoteBlue', 'user': 'Buzzporter', 'sentiment': {'pos': 0.112, 'neu': 0.888, 'neg': 0.0, 'compound': 0.34}, 'negative_pecentage': '0.00', 'neutral_percentage': '88.80', 'positive_percentage': '11.20', 'sentiment_type': 'positive'}, {'date': datetime.datetime(2020, 4, 18, 22, 8, 12, tzinfo=datetime.timezone.utc), 'text': '#Trump, YOU LIE!!!!! #Resist', 'user': 'EltonJane', 'sentiment': {'pos': 0.0, 'neu': 1.0, 'neg': 0.0, 'compound': 0.0}, 'negative_pecentage': '0.00', 'neutral_percentage': '100.00', 'positive_percentage': '0.00', 'sentiment_type': 'neutral'}, {'date': datetime.datetime(2020, 4, 18, 22, 8, 12, tzinfo=datetime.timezone.utc), 'text': 'After my lovely hour with @GovAndyBeshear, for shits and grins I turned over to #Trump. It took 20 seconds for me to switch over to @hgtv.', 'user': 'FatRatWithIron', 'sentiment': {'pos': 0.185, 'neu': 0.714, 'neg': 0.101, 'compound': 0.3818}, 'negative_pecentage': '10.10', 'neutral_percentage': '71.40', 'positive_percentage': '18.50', 'sentiment_type': 'positive'}, {'date': datetime.datetime(2020, 4, 18, 22, 8, 14, tzinfo=datetime.timezone. ...
# ========= 2020-04-18 17:08:30 =========
